# %% [markdown]
# <a href="https://colab.research.google.com/github/amiegirl/Arima_HDSC_winter_2022/blob/main/Arima_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem Statement

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Election, COVID, and Demographic Data by County: What Factors Influenced the USA 2020 Election?(https://www.kaggle.com/etsc9287/2020-general-election-polls)
# Awesome data compilation of “How Voting Was” in the years 2016, and 2020 (the COVID-19 year). As can be seen, there are definitely factors that caused a shift in the opinion of voters between 2016 and 2020. With this dataset, these factors can be found out, as well as other things responsible for the poll results in both years across the states.

# %% [markdown]
# # Importing required modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
from scipy.stats import skew
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.rcParams['figure.figsize'] = (15,12)

# %% [markdown]
# # Loading the Dataset

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/county_statistics.csv')
trump_clinton_df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/trump_clinton_polls.csv")
trump_biden_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/trump_biden_polls.csv")
trump_biden_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (6,22,25,29) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    question_id  poll_id  cycle         state  pollster_id  \
# 0       136283    72621   2020          Iowa          383
# 1       136283    72621   2020          Iowa          383
# 2       136322    72647   2020  Pennsylvania          461
# 3       136322    72647   2020  Pennsylvania          461
# 4       136322    72647   2020  Pennsylvania          461
#
#                               pollster sponsor_ids sponsors  \
# 0                Public Policy Polling         NaN      NaN
# 1                Public Policy Polling         NaN      NaN
# 2  Susquehanna Polling & Research Inc.         NaN      NaN
# 3  Susquehanna Polling & Research Inc.         NaN      NaN
# 4  Susquehanna Polling & Research Inc.         NaN      NaN
#
#                           display_name  pollster_rating_id  ...  \
# 0                Public Policy Polling               263.0  ...
# 1                Public Policy Polling               263.0  ...
# 2  Susquehanna Polling & Research Inc.               326.0  ...
# 3  Susquehanna Polling & Research Inc.               326.0  ...
# 4  Susquehanna Polling & Research Inc.               326.0  ...
#
#       created_at notes                                                url  \
# 0  11/2/20 09:02   NaN  https://www.publicpolicypolling.com/wp-content...
# 1  11/2/20 09:02   NaN  https://www.publicpolicypolling.com/wp-content...
# 2  11/2/20 12:49   NaN  https://www.realclearpolitics.com/docs/2020/Su...
# 3  11/2/20 12:49   NaN  https://www.realclearpolitics.com/docs/2020/Su...
# 4  11/2/20 12:49   NaN  https://www.realclearpolitics.com/docs/2020/Su...
#
#      stage race_id     answer candidate_id       candidate_name  \
# 0  general    6223      Biden        13256  Joseph R. Biden Jr.
# 1  general    6223      Trump        13254         Donald Trump
# 2  general    6249      Biden        13256  Joseph R. Biden Jr.
# 3  general    6249      Trump        13254         Donald Trump
# 4  general    6249  Jorgensen        14611         Jo Jorgensen
#
#    candidate_party   pct
# 0              DEM  49.0
# 1              REP  48.0
# 2              DEM  48.4
# 3              REP  49.2
# 4              LIB   1.4
#
# [5 rows x 38 columns]

# %%
trump_biden_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16438 entries, 0 to 16437
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   question_id                16438 non-null  int64
#  1   poll_id                    16438 non-null  int64
#  2   cycle                      16438 non-null  int64
#  3   state                      11385 non-null  object
#  4   pollster_id                16438 non-null  int64
#  5   pollster                   16438 non-null  object
#  6   sponsor_ids                9968 non-null   object
#  7   sponsors                   9968 non-null   object
#  8   display_name               16438 non-null  object
#  9   pollster_rating_id         16425 non-null  float64
#  10  pollster_rating_name       16425 non-null  object
#  11  fte_grade                  15253 non-null  object
#  12  sample_size                16436 non-null  float64
#  13  population                 16438 non-null  object
#  14  population_full            16438 non-null  object
#  15  methodology                16138 non-null  object
#  16  office_type                16438 non-null  object
#  17  seat_number                16438 non-null  int64
#  18  seat_name                  0 non-null      float64
#  19  start_date                 16438 non-null  object
#  20  end_date                   16438 non-null  object
#  21  election_date              16438 non-null  object
#  22  sponsor_candidate          54 non-null     object
#  23  internal                   16438 non-null  bool
#  24  partisan                   743 non-null    object
#  25  tracking                   6384 non-null   object
#  26  nationwide_batch           16438 non-null  bool
#  27  ranked_choice_reallocated  16438 non-null  bool
#  28  created_at                 16438 non-null  object
#  29  notes                      623 non-null    object
#  30  url                        16230 non-null  object
#  31  stage                      16438 non-null  object
#  32  race_id                    16438 non-null  int64
#  33  answer                     16438 non-null  object
#  34  candidate_id               16438 non-null  int64
#  35  candidate_name             16438 non-null  object
#  36  candidate_party            16438 non-null  object
#  37  pct                        16438 non-null  float64
# dtypes: bool(3), float64(4), int64(7), object(24)
# memory usage: 4.4+ MB

# %% [markdown]
# # Cleaning the Dataset

# %%
#dropping irrelevant columns
trump_biden_df.drop(columns=["notes", "seat_name", "sponsor_candidate", "partisan", "tracking"],inplace=True, axis=1)
trump_biden_df.head()
# Out:
#    question_id  poll_id  cycle         state  pollster_id  \
# 0       136283    72621   2020          Iowa          383
# 1       136283    72621   2020          Iowa          383
# 2       136322    72647   2020  Pennsylvania          461
# 3       136322    72647   2020  Pennsylvania          461
# 4       136322    72647   2020  Pennsylvania          461
#
#                               pollster sponsor_ids sponsors  \
# 0                Public Policy Polling         NaN      NaN
# 1                Public Policy Polling         NaN      NaN
# 2  Susquehanna Polling & Research Inc.         NaN      NaN
# 3  Susquehanna Polling & Research Inc.         NaN      NaN
# 4  Susquehanna Polling & Research Inc.         NaN      NaN
#
#                           display_name  pollster_rating_id  ...  \
# 0                Public Policy Polling               263.0  ...
# 1                Public Policy Polling               263.0  ...
# 2  Susquehanna Polling & Research Inc.               326.0  ...
# 3  Susquehanna Polling & Research Inc.               326.0  ...
# 4  Susquehanna Polling & Research Inc.               326.0  ...
#
#   ranked_choice_reallocated     created_at  \
# 0                     False  11/2/20 09:02
# 1                     False  11/2/20 09:02
# 2                     False  11/2/20 12:49
# 3                     False  11/2/20 12:49
# 4                     False  11/2/20 12:49
#
#                                                  url    stage race_id  \
# 0  https://www.publicpolicypolling.com/wp-content...  general    6223
# 1  https://www.publicpolicypolling.com/wp-content...  general    6223
# 2  https://www.realclearpolitics.com/docs/2020/Su...  general    6249
# 3  https://www.realclearpolitics.com/docs/2020/Su...  general    6249
# 4  https://www.realclearpolitics.com/docs/2020/Su...  general    6249
#
#       answer candidate_id       candidate_name candidate_party   pct
# 0      Biden        13256  Joseph R. Biden Jr.             DEM  49.0
# 1      Trump        13254         Donald Trump             REP  48.0
# 2      Biden        13256  Joseph R. Biden Jr.             DEM  48.4
# 3      Trump        13254         Donald Trump             REP  49.2
# 4  Jorgensen        14611         Jo Jorgensen             LIB   1.4
#
# [5 rows x 33 columns]

# %%
#droping rows with missing values
trump_biden_df = trump_biden_df.dropna()
trump_biden_df.isnull().sum()
# Out:
# question_id                  0
# poll_id                      0
# cycle                        0
# state                        0
# pollster_id                  0
# pollster                     0
# sponsor_ids                  0
# sponsors                     0
# display_name                 0
# pollster_rating_id           0
# pollster_rating_name         0
# fte_grade                    0
# sample_size                  0
# population                   0
# population_full              0
# methodology                  0
# office_type                  0
# seat_number                  0
# start_date                   0
# end_date                     0
# election_date                0
# internal                     0
# nationwide_batch             0
# ranked_choice_reallocated    0
# created_at                   0
# url                          0
# stage                        0
# race_id                      0
# answer                       0
# candidate_id                 0
# candidate_name               0
# candidate_party              0
# pct                          0
# dtype: int64

# %%
trump_biden_df.head()
# Out:
#     question_id  poll_id  cycle    state  pollster_id  \
# 5        136491    72722   2020  Florida          235
# 6        136491    72722   2020  Florida          235
# 7        136491    72722   2020  Florida          235
# 45       136341    72653   2020  Arizona          744
# 46       136341    72653   2020  Arizona          744
#
#                           pollster sponsor_ids       sponsors  \
# 5   Opinion Savvy/InsiderAdvantage         364  FOX35 Orlando
# 6   Opinion Savvy/InsiderAdvantage         364  FOX35 Orlando
# 7   Opinion Savvy/InsiderAdvantage         364  FOX35 Orlando
# 45                           Ipsos          71        Reuters
# 46                           Ipsos          71        Reuters
#
#         display_name  pollster_rating_id  ... ranked_choice_reallocated  \
# 5   InsiderAdvantage               243.0  ...                     False
# 6   InsiderAdvantage               243.0  ...                     False
# 7   InsiderAdvantage               243.0  ...                     False
# 45             Ipsos               154.0  ...                     False
# 46             Ipsos               154.0  ...                     False
#
#        created_at                                                url    stage  \
# 5   11/2/20 19:02  https://www.realclearpolitics.com/docs/2020/Fo...  general
# 6   11/2/20 19:02  https://www.realclearpolitics.com/docs/2020/Fo...  general
# 7   11/2/20 19:02  https://www.realclearpolitics.com/docs/2020/Fo...  general
# 45  11/2/20 14:25  https://www.ipsos.com/sites/default/files/ct/n...  general
# 46  11/2/20 14:25  https://www.ipsos.com/sites/default/files/ct/n...  general
#
#    race_id     answer candidate_id       candidate_name candidate_party   pct
# 5     6220      Biden        13256  Joseph R. Biden Jr.             DEM  47.0
# 6     6220      Trump        13254         Donald Trump             REP  48.2
# 7     6220  Jorgensen        14611         Jo Jorgensen             LIB   1.6
# 45    6214      Biden        13256  Joseph R. Biden Jr.             DEM  50.0
# 46    6214      Trump        13254         Donald Trump             REP  48.0
#
# [5 rows x 33 columns]

# %%
#Checking duplicate values
trump_biden_df.duplicated().any()
# Out:
# False

# %%
trump_clinton_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/trump_clinton_polls.csv')
trump_clinton_df.head()
# Out:
#    Unnamed: 0  start_date    end_date           state               pollster  \
# 0        3077  2015-11-07  2015-11-08  South Carolina  Public Policy Polling
# 1        6520  2015-11-07  2015-11-08  South Carolina  Public Policy Polling
# 2        9901  2015-11-07  2015-11-08  South Carolina  Public Policy Polling
# 3        3206  2015-11-09  2015-11-13        Virginia        Roanoke College
# 4        6638  2015-11-09  2015-11-13        Virginia        Roanoke College
#
#   fte_grade  sample_size population   Clinton     Trump  dem_lead
# 0        B+       1290.0          v  40.63694  45.19826  -4.56132
# 1        B+       1290.0          v  40.48820  45.19637  -4.70817
# 2        B+       1290.0          v  40.69941  45.18212  -4.48271
# 3        C+        555.0         rv  49.81532  36.21050  13.60482
# 4        C+        555.0         rv  49.00173  37.02524  11.97649

# %%
trump_clinton_df.rename(columns={'Unnamed: 0': 'S.No.'}, inplace=True)
trump_clinton_df.set_index(['S.No.'], inplace = True)
trump_clinton_df.head()
# Out:
#        start_date    end_date           state               pollster  \
# S.No.
# 3077   2015-11-07  2015-11-08  South Carolina  Public Policy Polling
# 6520   2015-11-07  2015-11-08  South Carolina  Public Policy Polling
# 9901   2015-11-07  2015-11-08  South Carolina  Public Policy Polling
# 3206   2015-11-09  2015-11-13        Virginia        Roanoke College
# 6638   2015-11-09  2015-11-13        Virginia        Roanoke College
#
#       fte_grade  sample_size population   Clinton     Trump  dem_lead
# S.No.
# 3077         B+       1290.0          v  40.63694  45.19826  -4.56132
# 6520         B+       1290.0          v  40.48820  45.19637  -4.70817
# 9901         B+       1290.0          v  40.69941  45.18212  -4.48271
# 3206         C+        555.0         rv  49.81532  36.21050  13.60482
# 6638         C+        555.0         rv  49.00173  37.02524  11.97649

# %%
trump_clinton_df.shape
# Out:
# (10236, 10)

# %%
trump_clinton_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10236 entries, 3077 to 6833
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   start_date   10236 non-null  object
#  1   end_date     10236 non-null  object
#  2   state        10236 non-null  object
#  3   pollster     10236 non-null  object
#  4   fte_grade    9102 non-null   object
#  5   sample_size  10233 non-null  float64
#  6   population   10236 non-null  object
#  7   Clinton      10236 non-null  float64
#  8   Trump        10236 non-null  float64
#  9   dem_lead     10236 non-null  float64
# dtypes: float64(4), object(6)
# memory usage: 879.7+ KB

# %%
trump_clinton_df.isnull().sum()
# Out:
# start_date        0
# end_date          0
# state             0
# pollster          0
# fte_grade      1134
# sample_size       3
# population        0
# Clinton           0
# Trump             0
# dem_lead          0
# dtype: int64

# %%
trump_clinton_df.duplicated().any()
# Out:
# False

# %%
plt.xticks(rotation = 90)

x1 = trump_clinton_df['state']
y1 = trump_clinton_df['Clinton']

plt.scatter(x1, y1, label = "Votes for Clinton")

x2 = trump_clinton_df['state']
y2 = trump_clinton_df['Trump']

plt.scatter(x2, y2, label = "Votes for Trump")
 
plt.xlabel('states')

plt.ylabel('Votes')

plt.title('State wise vote comparison')

plt.legend()

plt.show()

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/county_statistics.csv')
df.head()
# Out:
#    Unnamed: 0     county state  percentage16_Donald_Trump  \
# 0           0  Abbeville    SC                      0.629
# 1           1     Acadia    LA                      0.773
# 2           2   Accomack    VA                      0.545
# 3           3        Ada    ID                      0.479
# 4           4      Adair    IA                      0.653
#
#    percentage16_Hillary_Clinton  total_votes16  votes16_Donald_Trump  \
# 0                         0.346        10724.0                6742.0
# 1                         0.206        27386.0               21159.0
# 2                         0.428        15755.0                8582.0
# 3                         0.387       195587.0               93748.0
# 4                         0.300         3759.0                2456.0
#
#    votes16_Hillary_Clinton  percentage20_Donald_Trump  percentage20_Joe_Biden  \
# 0                   3712.0                      0.661                   0.330
# 1                   5638.0                      0.795                   0.191
# 2                   6737.0                      0.542                   0.447
# 3                  75676.0                      0.504                   0.465
# 4                   1127.0                      0.697                   0.286
#
#    ...  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  PrivateWork  \
# 0  ...   1.8          1.8         6.5         25.8    9505.0         78.8
# 1  ...   1.6          2.2         2.5         27.6   24982.0         80.0
# 2  ...   2.6          1.8         4.5         22.0   13837.0         74.6
# 3  ...   1.5          2.8         6.9         20.4  214984.0         78.3
# 4  ...   2.8          0.4         6.2         22.3    3680.0         73.8
#
#    PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0        13.3           7.8         0.1           9.4
# 1        12.1           7.6         0.3           8.9
# 2        18.1           7.1         0.2           5.4
# 3        15.0           6.6         0.1           4.3
# 4        15.3          10.4         0.5           3.0
#
# [5 rows x 51 columns]

# %%
df.shape
# Out:
# (4867, 51)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4867 entries, 0 to 4866
# Data columns (total 51 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    4867 non-null   int64
#  1   county                        4867 non-null   object
#  2   state                         4867 non-null   object
#  3   percentage16_Donald_Trump     3111 non-null   float64
#  4   percentage16_Hillary_Clinton  3111 non-null   float64
#  5   total_votes16                 3111 non-null   float64
#  6   votes16_Donald_Trump          3111 non-null   float64
#  7   votes16_Hillary_Clinton       3111 non-null   float64
#  8   percentage20_Donald_Trump     4490 non-null   float64
#  9   percentage20_Joe_Biden        4490 non-null   float64
#  10  total_votes20                 4633 non-null   float64
#  11  votes20_Donald_Trump          4633 non-null   float64
#  12  votes20_Joe_Biden             4633 non-null   float64
#  13  lat                           3252 non-null   float64
#  14  long                          3252 non-null   float64
#  15  cases                         3252 non-null   float64
#  16  deaths                        3252 non-null   float64
#  17  TotalPop                      3142 non-null   float64
#  18  Men                           3142 non-null   float64
#  19  Women                         3142 non-null   float64
#  20  Hispanic                      3142 non-null   float64
#  21  White                         3142 non-null   float64
#  22  Black                         3142 non-null   float64
#  23  Native                        3142 non-null   float64
#  24  Asian                         3142 non-null   float64
#  25  Pacific                       3142 non-null   float64
#  26  VotingAgeCitizen              3142 non-null   float64
#  27  Income                        3142 non-null   float64
#  28  IncomeErr                     3142 non-null   float64
#  29  IncomePerCap                  3142 non-null   float64
#  30  IncomePerCapErr               3142 non-null   float64
#  31  Poverty                       3142 non-null   float64
#  32  ChildPoverty                  3141 non-null   float64
#  33  Professional                  3142 non-null   float64
#  34  Service                       3142 non-null   float64
#  35  Office                        3142 non-null   float64
#  36  Construction                  3142 non-null   float64
#  37  Production                    3142 non-null   float64
#  38  Drive                         3142 non-null   float64
#  39  Carpool                       3142 non-null   float64
#  40  Transit                       3142 non-null   float64
#  41  Walk                          3142 non-null   float64
#  42  OtherTransp                   3142 non-null   float64
#  43  WorkAtHome                    3142 non-null   float64
#  44  MeanCommute                   3142 non-null   float64
#  45  Employed                      3142 non-null   float64
#  46  PrivateWork                   3142 non-null   float64
#  47  PublicWork                    3142 non-null   float64
#  48  SelfEmployed                  3142 non-null   float64
#  49  FamilyWork                    3142 non-null   float64
#  50  Unemployment                  3142 non-null   float64
# dtypes: float64(48), int64(1), object(2)
# memory usage: 1.9+ MB

# %%
#dropping the index column
df.drop(columns=['Unnamed: 0'],inplace=True)
df.head()
# Out:
#       county state  percentage16_Donald_Trump  percentage16_Hillary_Clinton  \
# 0  Abbeville    SC                      0.629                         0.346
# 1     Acadia    LA                      0.773                         0.206
# 2   Accomack    VA                      0.545                         0.428
# 3        Ada    ID                      0.479                         0.387
# 4      Adair    IA                      0.653                         0.300
#
#    total_votes16  votes16_Donald_Trump  votes16_Hillary_Clinton  \
# 0        10724.0                6742.0                   3712.0
# 1        27386.0               21159.0                   5638.0
# 2        15755.0                8582.0                   6737.0
# 3       195587.0               93748.0                  75676.0
# 4         3759.0                2456.0                   1127.0
#
#    percentage20_Donald_Trump  percentage20_Joe_Biden  total_votes20  ...  \
# 0                      0.661                   0.330        12433.0  ...
# 1                      0.795                   0.191        28425.0  ...
# 2                      0.542                   0.447        16938.0  ...
# 3                      0.504                   0.465       259389.0  ...
# 4                      0.697                   0.286         4183.0  ...
#
#    Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  PrivateWork  \
# 0   1.8          1.8         6.5         25.8    9505.0         78.8
# 1   1.6          2.2         2.5         27.6   24982.0         80.0
# 2   2.6          1.8         4.5         22.0   13837.0         74.6
# 3   1.5          2.8         6.9         20.4  214984.0         78.3
# 4   2.8          0.4         6.2         22.3    3680.0         73.8
#
#    PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0        13.3           7.8         0.1           9.4
# 1        12.1           7.6         0.3           8.9
# 2        18.1           7.1         0.2           5.4
# 3        15.0           6.6         0.1           4.3
# 4        15.3          10.4         0.5           3.0
#
# [5 rows x 50 columns]

# %%
#checking null values
df.isna().sum()
# Out:
# county                             0
# state                              0
# percentage16_Donald_Trump       1756
# percentage16_Hillary_Clinton    1756
# total_votes16                   1756
# votes16_Donald_Trump            1756
# votes16_Hillary_Clinton         1756
# percentage20_Donald_Trump        377
# percentage20_Joe_Biden           377
# total_votes20                    234
# votes20_Donald_Trump             234
# votes20_Joe_Biden                234
# lat                             1615
# long                            1615
# cases                           1615
# deaths                          1615
# TotalPop                        1725
# Men                             1725
# Women                           1725
# Hispanic                        1725
# White                           1725
# Black                           1725
# Native                          1725
# Asian                           1725
# Pacific                         1725
# VotingAgeCitizen                1725
# Income                          1725
# IncomeErr                       1725
# IncomePerCap                    1725
# IncomePerCapErr                 1725
# Poverty                         1725
# ChildPoverty                    1726
# Professional                    1725
# Service                         1725
# Office                          1725
# Construction                    1725
# Production                      1725
# Drive                           1725
# Carpool                         1725
# Transit                         1725
# Walk                            1725
# OtherTransp                     1725
# WorkAtHome                      1725
# MeanCommute                     1725
# Employed                        1725
# PrivateWork                     1725
# PublicWork                      1725
# SelfEmployed                    1725
# FamilyWork                      1725
# Unemployment                    1725
# dtype: int64

# %%
#checking duplicated values
df.duplicated().any()
# Out:
# False

# %% [markdown]
# # EDA

# %%
# Summary of the dataset
df.describe()
# Out:
#        percentage16_Donald_Trump  percentage16_Hillary_Clinton  total_votes16  \
# count                3111.000000                   3111.000000   3.111000e+03
# mean                    0.636195                      0.316813   4.091585e+04
# std                     0.156098                      0.153265   1.082702e+05
# min                     0.041000                      0.031000   6.400000e+01
# 25%                     0.550000                      0.204500   4.824500e+03
# 50%                     0.667000                      0.285000   1.093500e+04
# 75%                     0.750500                      0.399000   2.867500e+04
# max                     0.953000                      0.928000   2.314275e+06
#
#        votes16_Donald_Trump  votes16_Hillary_Clinton  \
# count           3111.000000             3.111000e+03
# mean           19349.902604             1.956652e+04
# std            39130.388677             6.848931e+04
# min               57.000000             4.000000e+00
# 25%             3207.000000             1.164500e+03
# 50%             7117.000000             3.140000e+03
# 75%            17396.500000             9.536500e+03
# max           590465.000000             1.654626e+06
#
#        percentage20_Donald_Trump  percentage20_Joe_Biden  total_votes20  \
# count                4490.000000             4490.000000   4.633000e+03
# mean                    0.585702                0.394531   3.316812e+04
# std                     0.183775                0.180909   1.189115e+05
# min                     0.000000                0.031000   0.000000e+00
# 25%                     0.454000                0.245000   2.313000e+03
# 50%                     0.604000                0.376000   7.461000e+03
# 75%                     0.736000                0.524000   1.994700e+04
# max                     0.962000                1.000000   4.139895e+06
#
#        votes20_Donald_Trump  votes20_Joe_Biden  ...         Walk  OtherTransp  \
# count          4.633000e+03       4.633000e+03  ...  3142.000000   3142.00000
# mean           1.568986e+04       1.688328e+04  ...     3.235455      1.60331
# std            4.402918e+04       7.620998e+04  ...     3.916257      1.68188
# min            0.000000e+00       0.000000e+00  ...     0.000000      0.00000
# 25%            1.232000e+03       7.380000e+02  ...     1.400000      0.90000
# 50%            4.343000e+03       2.413000e+03  ...     2.300000      1.30000
# 75%            1.225800e+04       7.359000e+03  ...     3.800000      1.90000
# max            1.107090e+06       2.947568e+06  ...    59.200000     43.20000
#
#         WorkAtHome  MeanCommute      Employed  PrivateWork   PublicWork  \
# count  3142.000000  3142.000000  3.142000e+03  3142.000000  3142.000000
# mean      4.802960    23.354870  4.793099e+04    75.069478    16.891025
# std       3.076183     5.638348  1.576220e+05     7.553859     6.276469
# min       0.000000     5.100000  3.900000e+01    31.100000     4.400000
# 25%       2.900000    19.600000  4.550500e+03    71.700000    12.700000
# 50%       4.100000    23.100000  1.069500e+04    76.300000    15.700000
# 75%       5.800000    26.900000  2.951475e+04    80.300000    19.500000
# max      33.000000    45.100000  4.805817e+06    88.800000    64.800000
#
#        SelfEmployed   FamilyWork  Unemployment
# count   3142.000000  3142.000000   3142.000000
# mean       7.758116     0.282368      6.364004
# std        3.866815     0.451699      3.063165
# min        0.000000     0.000000      0.000000
# 25%        5.200000     0.100000      4.400000
# 50%        6.800000     0.200000      6.100000
# 75%        9.175000     0.300000      7.800000
# max       38.000000     8.000000     28.800000
#
# [8 rows x 48 columns]

# %%
#Comparing total votes in 2016 to 2020
print ('Total votes in year 2016 is:',df['total_votes16'].sum())
print ('Total votes in year 2020 is:',df['total_votes20'].sum())
# Out:
# Total votes in year 2016 is: 127289217.0
# Total votes in year 2020 is: 153667887.0

# %% [markdown]
# More people voted in year 2020 than 2016

# %%
#Total votes by state in year 2020
df.groupby('state')['total_votes20'].sum().sort_values(ascending = False)
# Out:
# state
# CA    16092730.0
# TX    11255671.0
# FL    11075446.0
# PA     6804083.0
# IL     6784154.0
# NY     6647018.0
# OH     5764587.0
# MI     5531329.0
# NC     5474442.0
# GA     4992420.0
# VA     4443375.0
# NJ     4033007.0
# WA     4004599.0
# MA     3482216.0
# AZ     3366867.0
# WI     3297174.0
# MN     3272469.0
# CO     3216881.0
# TN     3049514.0
# IN     3032024.0
# MO     3010316.0
# MD     2729976.0
# SC     2513329.0
# OR     2349283.0
# AL     2309900.0
# LA     2148062.0
# KY     2135193.0
# CT     1821878.0
# IA     1687692.0
# OK     1560699.0
# UT     1435687.0
# NV     1337217.0
# KS     1334330.0
# AR     1209372.0
# MS     1159362.0
# NE      942480.0
# NM      921308.0
# ID      867971.0
# NH      804453.0
# WV      790253.0
# ME      786337.0
# MT      602781.0
# HI      573854.0
# RI      513503.0
# DE      504010.0
# SD      422609.0
# VT      367432.0
# ND      361656.0
# DC      309190.0
# WY      276765.0
# AK      260983.0
# Name: total_votes20, dtype: float64

# %% [markdown]
# States with the highest votes in 2020 are; CL(Carlifonia), TX(Texas), and FL(Florida)

# %%
#Total votes by state
df.groupby('state')['total_votes16','total_votes20'].sum().plot(kind = 'bar')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
#checking Totalpopulation
df['TotalPop'].sum()
# Out:
# 321004407.0

# %%
#checking total number of cases
df['cases'].sum()
# Out:
# 9134085.0

# %%
df['deaths'].sum()
# Out:
# 230062.0

# %%
plt.rcParams['figure.figsize'] = (30,15)
sns.heatmap(df.corr(),annot=True)

# %%
sns.heatmap(df.corr()[['total_votes20']].sort_values('total_votes20').tail(100),vmax=1, vmin=-1, annot=True).invert_yaxis()

# %% [markdown]
# Employed persons was the biggest factor that affected the 2020 elections

# %%
df['diffInWinTrumpClinton'] = df['percentage16_Donald_Trump']- df['percentage16_Hillary_Clinton'] 
df['diffInLossTrumpBiden'] = df['percentage20_Joe_Biden'] - df['percentage20_Donald_Trump']

# %%
sns.heatmap(df.corr()[['diffInWinTrumpClinton']].sort_values('diffInWinTrumpClinton').tail(100), vmax=1, vmin=-1, annot=True).invert_yaxis()

# %%
sns.heatmap(df.corr()[['diffInLossTrumpBiden']].sort_values('diffInLossTrumpBiden').tail(100), vmax=1, vmin=-1, annot=True).invert_yaxis()

# %%
# As is visible from the heatmap, the variable Employed seems to be most correlated with the 2020 votes
# Race-Asian,Black also demostrated some correlation
# So let's go ahead and perform simple linear regression

# %%
#Checking relationship between features and response
sns.pairplot(df,x_vars=['Employed','Asian','Black','White'],y_vars='total_votes20',height=7,aspect=0.7)

# %% [markdown]
# Race: Asians and Blacks were the great differential
